# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
# importing the datasets or files
df_booking = pd.read_csv('Datasets/fact_bookings.csv')
df_hotels = pd.read_csv('Datasets/dim_hotels.csv')
df_rooms = pd.read_csv('Datasets/dim_rooms.csv')
df_agg_bookings = pd.read_csv('Datasets/fact_aggregated_bookings.csv')
df_aug_data = pd.read_csv('Datasets/new_data_august.csv')

df_booking.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100

# %%
df_booking.shape
# Out:
# (134590, 12)

# %%
df_booking.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_booking.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
# count of bookings per plateform 
df_booking.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
# ploting a cahrt 
df_booking.booking_platform.value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
# ploting bar chart hozitontally
df_booking.booking_platform.value_counts().plot(kind= 'barh')
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_booking.revenue_generated.min(), df_booking.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values() #
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
# plot a bar chart for that
df_hotels.city.value_counts().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# # Data Cleaning

# %%
df_booking.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640

# %%
# checking the data
df_booking[df_booking.no_guests<0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134590, 12)

# %%
df_booking = df_booking[df_booking.no_guests>0]
df_booking
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_booking.shape
# Out:
# (134578, 12)

# %% [markdown]
# Now -ve values are removed from the dataset

# %%
# checking for the revenue_generated column
df_booking.revenue_generated.min(), df_booking.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
# applying Std in revenue_generated column
avg, std = df_booking.revenue_generated.mean(),df_booking.revenue_generated.std()

# %%
avg, std
# Out:
# (15378.036937686695, 93040.1549314641)

# %%
higer_limit = avg + 3*std
higer_limit
# Out:
# 294498.50173207896

# %%
lower_limit = avg - 3*std
lower_limit
# Out:
# -263742.4278567056

# %%
# my revenue generated should not be negative
df_booking[df_booking.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %% [markdown]
# - there is no such any -ve revenue generated in our dataset

# %%
# outlier in revenue generated column
df_booking[df_booking.revenue_generated>higer_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %% [markdown]
# - these are the outlier for the revenue_generated column. and he can remove them using reverse condition

# %%
df_booking = df_booking[df_booking.revenue_generated< higer_limit]

# %%
df_booking.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920

# %%
df_booking.shape
# Out:
# (134573, 12)

# %%
# checking the revenue_realized column
df_booking.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit = df_booking.revenue_realized.mean() + 3* df_booking.revenue_realized.std()
higher_limit
# Out:
# 33479.358661845814

# %%
df_booking[df_booking.revenue_realized > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %% [markdown]
# - here RT4 reknown as presidential room class and these types of rooms are really expensive as compared to any other in our dataset so we as per this reason i can say that these 1299 raws are not an outler it's high pawing room type in hotels.
#
# - for this problem we get std only for the entire RT4 rooms and apply them.

# %%
df_booking[df_booking.room_category == "RT4"]  # these all are the rt4 rooms
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 47       May012216558RT41        16558     26-04-22      1/5/2022
# 48       May012216558RT42        16558     27-04-22      1/5/2022
# 49       May012216558RT43        16558     29-04-22      1/5/2022
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 138      May012216559RT42        16559    11/4/2022      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 47          3/5/2022        2.0           RT4          logtrip            NaN
# ...

# %%
df_booking[df_booking.room_category == "RT4"].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %% [markdown]
# - for this std for only rt4 rooms first we need to check your higher limit for the rt4 rooms.

# %%
higher_limit = 23439 + 3*9048
higher_limit
# Out:
# 50583

# %% [markdown]
# - as we can see that our higher_limit for the rt4 rooms are 50583, but in our dataset rt4 having highest revenue 45220 max, means here is no any outlier, thats comform.

# %% [markdown]
# # Isna Values

# %%
df_booking.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# # Data Transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 3           17558      1-May-22           RT1                   30      19.0
# 4           16558      1-May-22           RT1                   18      19.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#        occ_pct
# 0     0.833333
# ...

# %%
df_agg_bookings["occ_pct"] = df_agg_bookings["occ_pct"].apply(lambda x : round(x*100,2))
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 3   157.89

# %% [markdown]
# # Some Ad-Hoc requests from the manager:

# %% [markdown]
# - **=> 1.What is the avg occupancy rate in each of the room categories?**

# %%
df_agg_bookings.groupby('room_category')['occ_pct'].mean().round(2)
# Out:
# room_category
# RT1    58.22
# RT2    58.04
# RT3    58.03
# RT4    59.30
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
# We are merging the df_rooms and df_agg_bookings to getting more insights

# %%
df = pd.merge(df_agg_bookings, df_rooms, left_on= 'room_category', right_on='room_id')
df.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3   157.89     RT1   Standard
# 4    94.74     RT1   Standard

# %%
# Now checking the avg occupancy rate in each of the room categories 
df.groupby('room_class')['occ_pct'].mean().round(2)
# Out:
# room_class
# Elite           58.04
# Premium         58.03
# Presidential    59.30
# Standard        58.22
# Name: occ_pct, dtype: float64

# %%
df.drop('room_id', axis= 1, inplace = True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3   157.89   Standard
# 4    94.74   Standard

# %% [markdown]
# # 2. Print the Average Occupancy rate per City

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
# merging the df and df_hotel tables
df = pd.merge(df, df_hotels, on = 'property_id' )
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
# 4        16559      5-May-22           RT1                   16      30.0
#
#    occ_pct room_class  property_name category    city
# 0    83.33   Standard  Atliq Exotica   Luxury  Mumbai
# 1    66.67   Standard  Atliq Exotica   Luxury  Mumbai
# 2    56.67   Standard  Atliq Exotica   Luxury  Mumbai
# 3    70.00   Standard  Atliq Exotica   Luxury  Mumbai
# 4    53.33   Standard  Atliq Exotica   Luxury  Mumbai

# %%
# now printing the avg occ rate per city
df.groupby('city')['occ_pct'].mean().round(2)
# Out:
# city
# Bangalore    56.59
# Delhi        61.61
# Hyderabad    58.14
# Mumbai       57.94
# Name: occ_pct, dtype: float64

# %%
# ploting city wise avg occ rate in bar chart
df.groupby('city')['occ_pct'].mean().round(2).plot(kind= 'barh')
# Out:
# <Axes: ylabel='city'>

# %% [markdown]
# # 3. When Was the Occ Better? Weekday Or Weekend?

# %%
df_date = pd.read_csv('Datasets/dim_date.csv')
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
# merging the df-date with df table
df = pd.merge(df, df_date, left_on = 'check_in_date', right_on = 'date')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559     10-May-22           RT1                   18      30.0
# 1        16559     10-May-22           RT2                   25      41.0
# 2        16559     10-May-22           RT3                   20      32.0
# 3        16559     10-May-22           RT4                   13      18.0
# 4        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct    room_class  property_name category       city       date  \
# 0    60.00      Standard  Atliq Exotica   Luxury     Mumbai  10-May-22
# 1    60.98         Elite  Atliq Exotica   Luxury     Mumbai  10-May-22
# 2    62.50       Premium  Atliq Exotica   Luxury     Mumbai  10-May-22
# 3    72.22  Presidential  Atliq Exotica   Luxury     Mumbai  10-May-22
# 4    60.00      Standard      Atliq Bay   Luxury  Bangalore  10-May-22
#
#    mmm yy week no  day_type
# 0  May 22    W 20  weekeday
# 1  May 22    W 20  weekeday
# ...

# %%
# getting thaat When Was the Occ Better
df.groupby('day_type')['occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    50.90
# weekend     72.39
# Name: occ_pct, dtype: float64

# %% [markdown]
# # 4. In the month of June, what is the occupancy for different cities

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_jun_22 = df[df['mmm yy']== 'Jun 22']
df_jun_22.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        16559     10-Jun-22           RT2                   26      41.0
# 2202        16559     10-Jun-22           RT3                   20      32.0
#
#       occ_pct room_class  property_name category    city       date  mmm yy  \
# 2200    66.67   Standard  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
# 2201    63.41      Elite  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
# 2202    62.50    Premium  Atliq Exotica   Luxury  Mumbai  10-Jun-22  Jun 22
#
#      week no  day_type
# 2200    W 24  weekeday
# 2201    W 24  weekeday
# 2202    W 24  weekeday

# %%
# getting In the month of June, what is the occupancy for different cities
df_jun_22.groupby('city')['occ_pct'].mean().round(2)
# Out:
# city
# Bangalore    56.58
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Name: occ_pct, dtype: float64

# %%
df_aug_data.columns
# Out:
# Index(['property_id', 'property_name', 'category', 'city', 'room_category',
#        'room_class', 'check_in_date', 'mmm yy', 'week no', 'day_type',
#        'successful_bookings', 'capacity', 'occ%'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'room_class', 'property_name', 'category',
#        'city', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_aug_data.shape
# Out:
# (7, 13)

# %%
df.shape
# Out:
# (6500, 14)

# %%
latest_df = pd.concat([df, df_aug_data], ignore_index= True, axis = 0 )
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6497        18560     31-Jul-22           RT2                   34      40.0
# 6498        18560     31-Jul-22           RT3                   17      24.0
# 6499        18560     31-Jul-22           RT4                   12      15.0
# 6500        16559     01-Aug-22           RT1                   30      30.0
# 6501        19562     01-Aug-22           RT1                   21      30.0
# 6502        19563     01-Aug-22           RT1                   23      30.0
# 6503        19558     01-Aug-22           RT1                   30      40.0
# 6504        19560     01-Aug-22           RT1                   20      26.0
# 6505        17561     01-Aug-22           RT1                   18      26.0
# 6506        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class  property_name  category       city       date  \
# ...

# %% [markdown]
# # 6. Print revenue realized per City

# %%
df_hotels.head(2)
# Out:
#    property_id  property_name category    city
# 0        16558   Atliq Grands   Luxury   Delhi
# 1        16559  Atliq Exotica   Luxury  Mumbai

# %%
df_booking.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 4              10920             10920

# %%
df_booking_all = pd.merge(df_booking, df_hotels, on = 'property_id')
df_booking_all.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
# revenue realized per City
df_booking_all.groupby('city')['revenue_realized'].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %% [markdown]
# # 7. Print month by month revenue

# %%
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df_date['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
# merging the df_booking_all with df-date
pd.merge(df_booking_all, df_date, left_on ='check_in_date', right_on='date')
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, property_name, category, city, date, mmm yy, week no, day_type]
# Index: []

# %%
df_booking_all.info(), df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %% [markdown]
# - both columnm date are in obj now we need to change its types into datetype

# %%
df_date["date"] = pd.to_datetime(df_date['date'])
df_date['date'].head()
# Out:
# C:\Users\mrinn\AppData\Local\Temp\ipykernel_21388\930262336.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date["date"] = pd.to_datetime(df_date['date'])
# 0   2022-05-01
# 1   2022-05-02
# 2   2022-05-03
# 3   2022-05-04
# 4   2022-05-05
# Name: date, dtype: datetime64[ns]

# %%
df_booking_all['check_in_date'] = pd.to_datetime(df_booking_all['check_in_date'], format='%d-%m-%y', dayfirst=True, errors='coerce')
df_booking_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22           NaT      2/5/2022
# 1  May012216558RT15        16558     27-04-22           NaT      2/5/2022
# 2  May012216558RT16        16558     1/5/2022           NaT      3/5/2022
# 3  May012216558RT17        16558     28-04-22           NaT      6/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# ...

# %%
# checking the info
df_booking_all.info(), df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      78783 non-null   datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
# merging the df_booking_all with df-date
df_booking_all = pd.merge(df_booking_all, df_date, left_on ='check_in_date', right_on='date')
df_booking_all.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May132216558RT11        16558    10/5/2022    2022-05-13      15-05-22
# 1  May132216558RT12        16558     9/5/2022    2022-05-13      14-05-22
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1          logtrip            5.0    Checked Out
# 1        2.0           RT1     makeyourtrip            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              9100  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no  day_type
# 0 2022-05-13  May 22    W 20  weekeday
# 1 2022-05-13  May 22    W 20  weekeday

# %%
# getting the month by month revenue
df_booking_all.groupby('mmm yy')['revenue_realized'].sum()
# Out:
# mmm yy
# Jul 22    329662416
# Jun 22    324288215
# May 22    347414213
# Name: revenue_realized, dtype: int64
